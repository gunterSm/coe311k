# %%
#DISCUSSION OF RESULTS

#For Jacobian, we notice how using being less lenient tolerances yields a higher number of iterations for the method to be closer to an approximate answer.

#For Gaussian, we notice that using more strict tolerances is also yielding a higher number of iterations for every time it gets more strict.
#For Gaussian, we also notice that it is using fewer iterations than the Jacobian- which is because it is using updated information for each iteration and therefore needs less iterations to get to a closer value and ends dropping the algorithm quicker.

#Quick note: I added counters for all of the functions because I wanted to see the runtimes for each

# %%
#Jacobian method with Tolerance of 10^-3
import time
import numpy as np
import matplotlib.pyplot as plt
def jacobi(A, b, x0, tol, max_iterations):
    Error_plot = []
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        plot1 = np.linalg.norm(x_new - x, ord=np.inf)
        Error_plot.append(plot1)
# Check for convergence
        if plot1 < tol:
            return x_new, k, Error_plot
        x = x_new
    return x, max_iterations, Error_plot

#Matrices 
A = np.array([[3, -0.1, -0.2],
              [0.1, 7, -0.3],
              [0.3, -0.2, 10]])

b = np.array([7.85, -19.3, 71.4], dtype='float32')

x0 = np.zeros_like(b)

tol = 1e-3
max_iterations = 100
start_time = time.perf_counter()

solution, iterations, Error_plot = jacobi(A, b, x0, tol, max_iterations)

end_time = time.perf_counter()
elapsed_time = end_time - start_time

print("The elapsed time was:", elapsed_time, "seconds")
print(f"Solution Vector: {solution}")
print(f"Iterations: {iterations}")
print(f"Error Points: {Error_plot}")
# Out:
# The elapsed time was: 0.0003851950168609619 seconds
# Solution Vector: [ 3.0000224 -2.5000026  6.9999814]
# Iterations: 3
# Error Points: [7.1400003, 0.38409543, 0.011214495, 0.0007839203]

# %%
#Jacobian method with Tolerance of 10^-6
import time
import numpy as np
import matplotlib.pyplot as plt
def jacobi(A, b, x0, tol, max_iterations):
    Error_plot2 = []
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        plot2 = np.linalg.norm(x_new - x, ord=np.inf)
        Error_plot2.append(plot2)
# Check for convergence
        if plot2 < tol:
            return x_new, k, Error_plot2
        x = x_new
    return x, max_iterations, Error_plot2

#Matrices 
A = np.array([[3, -0.1, -0.2],
              [0.1, 7, -0.3],
              [0.3, -0.2, 10]])

b = np.array([7.85, -19.3, 71.4],  dtype='float32')

x0 = np.zeros_like(b)

tol = 1e-6
max_iterations = 100
start_time = time.perf_counter()

solution, iterations, Error_plot2 = jacobi(A, b, x0, tol, max_iterations)

end_time = time.perf_counter()
elapsed_time = end_time - start_time

print("The elapsed time was:", elapsed_time, "seconds")
print(f"Solution Vector: {solution}")
print(f"Iterations: {iterations}")
print(f"Error Points: {Error_plot2}")
# Out:
# The elapsed time was: 0.0007827263325452805 seconds
# Solution Vector: [ 3.  -2.5  7. ]
# Iterations: 6
# Error Points: [7.1400003, 0.38409543, 0.011214495, 0.0007839203, 2.3841858e-05, 1.4305115e-06, 0.0]

# %%
#Jacobian method with Tolerance of 10^-9
import time
import numpy as np
import matplotlib.pyplot as plt
def jacobi(A, b, x0, tol, max_iterations):
    Error_plot3 = []
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        plot3 = np.linalg.norm(x_new - x, ord=np.inf)
        Error_plot3.append(plot3)
# Check for convergence
        if plot3 < tol:
            return x_new, k, Error_plot3
        x = x_new
    return x, max_iterations, Error_plot3

#Matrices 
A = np.array([[3, -0.1, -0.2],
              [0.1, 7, -0.3],
              [0.3, -0.2, 10]])

b = np.array([7.85, -19.3, 71.4],  dtype='float32')

x0 = np.zeros_like(b)

tol = 1e-9
max_iterations = 100
start_time = time.perf_counter()

solution, iterations, Error_plot3 = jacobi(A, b, x0, tol, max_iterations)

end_time = time.perf_counter()
elapsed_time = end_time - start_time

print("The elapsed time was:", elapsed_time, "seconds")
print(f"Solution Vector: {solution}")
print(f"Iterations: {iterations}")
print(f"Error Points: {Error_plot3}")
# Out:
# The elapsed time was: 0.0007637646049261093 seconds
# Solution Vector: [ 3.  -2.5  7. ]
# Iterations: 6
# Error Points: [7.1400003, 0.38409543, 0.011214495, 0.0007839203, 2.3841858e-05, 1.4305115e-06, 0.0]

# %%
#Plotting

plt.plot(Error_plot, marker='v',label= "Absolute Error for tolerance of 10^-3", color = 'k')
plt.plot(Error_plot2, marker='D',label= "Absolute Error for tolerance of 10^-6", color = 'b')
plt.plot(Error_plot3, marker='*',label= "Absolute Error for tolerance of 10^-9", color = 'y')
plt.xlabel("Iterations")
plt.ylabel("Error")
plt.legend()
plt.show()

#For this part I noticed that all my lines overlapped, so I asked google if there were any code sources I could use to make a better disctinction and came up with the "markers"

# %%
#Gaussian Model with Tolerance of 10^-3
import time
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    Gauss = []
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        p = np.linalg.norm(x_new - x, ord=np.inf)
        Gauss.append(p)    
# Check for convergence
        if p < tol:
           return x_new, k, Gauss
        x = x_new
    return x, max_iterations, Gauss
#Example Usage
A = np.array([[3, -0.1, -0.2],
              [0.1, 7, -0.3],
              [0.3, -0.2, 10]])

b = np.array([7.85, -19.3, 71.4],  dtype='float32')

x0 = np.zeros_like(b)
tol = 1e-3
max_iterations = 100
start_time = time.perf_counter()

solution, iterations, Gauss = gauss_seidel(A, b, x0, tol, max_iterations)

end_time = time.perf_counter()
elapsed_time = end_time - start_time

print("The elapsed time was:", elapsed_time, "seconds")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Gaussian for Tolerance of 10^-3: {Gauss}")
print("\n")

#Gaussian Model with Tolerance of 10^-6
import time
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    Gauss1 = []
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        p = np.linalg.norm(x_new - x, ord=np.inf)
        Gauss1.append(p)    
# Check for convergence
        if p < tol:
           return x_new, k, Gauss1
        x = x_new
    return x, max_iterations, Gauss1
#Example Usage
A = np.array([[3, -0.1, -0.2],
              [0.1, 7, -0.3],
              [0.3, -0.2, 10]])

b = np.array([7.85, -19.3, 71.4],  dtype='float32')

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
start_time = time.perf_counter()

solution, iterations, Gauss1 = gauss_seidel(A, b, x0, tol, max_iterations)

end_time = time.perf_counter()
elapsed_time = end_time - start_time

print("The elapsed time was:", elapsed_time, "seconds")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Gaussian for Tolerance of 10^-6: {Gauss1}")
print("\n")

#Gaussian Model with Tolerance of 10^-9
import time
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    Gauss2 = []
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        p = np.linalg.norm(x_new - x, ord=np.inf)
        Gauss2.append(p)    
# Check for convergence
        if p < tol:
           return x_new, k, Gauss2
        x = x_new
    return x, max_iterations, Gauss2
#Example Usage
A = np.array([[3, -0.1, -0.2],
              [0.1, 7, -0.3],
              [0.3, -0.2, 10]])

b = np.array([7.85, -19.3, 71.4],  dtype='float32')

x0 = np.zeros_like(b)
tol = 1e-9
max_iterations = 100
start_time = time.perf_counter()

solution, iterations, Gauss2 = gauss_seidel(A, b, x0, tol, max_iterations)

end_time = time.perf_counter()
elapsed_time = end_time - start_time

print("The elapsed time was:", elapsed_time, "seconds")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Gaussian for Tolerance of 10^-9: {Gauss2}")
print("\n")
# Out:
# The elapsed time was: 0.0003161635249853134 seconds
# Solution: [ 3.0000002 -2.5        7.       ]
# Iterations: 3
# Gaussian for Tolerance of 10^-3: [7.0056095, 0.37388992, 0.00947547, 3.170967e-05]
#
#
# The elapsed time was: 0.0004392676055431366 seconds
# Solution: [ 3.  -2.5  7. ]
# Iterations: 4
# Gaussian for Tolerance of 10^-6: [7.0056095, 0.37388992, 0.00947547, 3.170967e-05, 2.3841858e-07]
#
#
# The elapsed time was: 0.00044203363358974457 seconds
# Solution: [ 3.  -2.5  7. ]
# Iterations: 5
# Gaussian for Tolerance of 10^-9: [7.0056095, 0.37388992, 0.00947547, 3.170967e-05, 2.3841858e-07, 0.0]

# %%
#Plotting

plt.plot(Gauss, marker='x',label= "Absolute Error for tolerance of 10^-3", color = 'm')
plt.plot(Gauss1, marker='o',label= "Absolute Error for tolerance of 10^-6", color = 'g')
plt.plot(Gauss2, marker='.',label= "Absolute Error for tolerance of 10^-9", color = 'b')
plt.xlabel("Iterations")
plt.ylabel("Error")
plt.legend()
plt.show()

# %%
#Plotting between both methods(If required)
plt.plot(Error_plot, marker='v',label= "Absolute Error for Jacobian tolerance of 10^-3", color = 'k')
plt.plot(Error_plot2, marker='D',label= "Absolute Error for Jacobian tolerance of 10^-6", color = 'b')
plt.plot(Error_plot3, marker='*',label= "Absolute Error for Jacobian tolerance of 10^-9", color = 'y')
plt.plot(Gauss, marker='x',label= "Absolute Error for Gaussian tolerance of 10^-3", color = 'm')
plt.plot(Gauss1, marker='o',label= "Absolute Error for Gaussian tolerance of 10^-6", color = 'g')
plt.plot(Gauss2, marker='.',label= "Absolute Error for Gaussian tolerance of 10^-9", color = 'b')
plt.xlabel("Iterations")
plt.ylabel("Error")
plt.legend()
plt.show()
