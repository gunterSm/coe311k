# %%
#Challenge Part 1
import numpy as np
import matplotlib.pyplot as plt

# Data points

X = np.array([1, 2, 3, 4, 5])

Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

# Stack the design matrix with a column of ones (for the intercept)

A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares

m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")


plt.scatter(X,Y, marker = 'o', color = 'g')
plt.plot(X, m*X+c, linestyle= 'solid')
plt.title("Best Fitting Line")
plt.show()
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
#Challenge Part 2
import numpy as np
import matplotlib.pyplot as plt

# Data points
n = 10
X = np.random.rand(n)

Y = np.random.rand(n)
#I searched this part, I did not know how to sort the X vector
idx = np.argsort(X)
X = X[idx]

Y = Y[idx]

# Stack the design matrix with a column of ones (for the intercept)

A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares

m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")

plt.scatter(X,Y, marker = '*', color = 'y')
plt.plot(X, m*X+c, linestyle= 'solid', color= 'k')
plt.title("Best Fitting Line")
plt.show()

#The line is not an accurate representation of the linearity between the data set as it is on the original matrices we had.
# Out:
# Slope: -0.08582258296453384, Intercept: 0.2807761811422215

# %%
#Challenge Part 3
import numpy as np
import matplotlib.pyplot as plt

#My equation is y = 3.5x + 8

s = 3.5
t = 8

X = np.arange(0, 1, 0.01)

Y = s*X + t

#The noise
noise = 3*(np.random.rand(len(X))- 0.5)

# Stack the design matrix with a column of ones (for the intercept)
y = Y - noise

A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares

m, c = np.linalg.lstsq(A, y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")


plt.scatter(X,y, marker = '^', color = 'c')
plt.plot(X, m*X+c, linestyle= 'solid', color = 'k')
plt.title("Best Fitting Line")
plt.show()

#Residuals
y_predicted = m*X +c
res = y - y_predicted

print("This is the largest residual:", np.max(res))
print("This is the smallest residual:", np.min(res))
# Out:
# Slope: 2.9082081844820027, Intercept: 8.236146025819806
# This is the largest residual: 1.7199892876033207
# This is the smallest residual: -1.6393705195211412
