# %%
import numpy as np
import matplotlib.pyplot as plt

# Function representing dy/dx = -2y
def f(x, y):
    return -2 * y
x_start, x_end = 0, 2

# Define parameters
for h in np.arange(0.1, 1, 0.05):
    num_steps = int((x_end - x_start) / h)
    accumulated_error = 0
    x_values = np.linspace(x_start, x_end, num_steps + 1)
    y_values = np.zeros(num_steps + 1)
    running_error = np.zeros(num_steps + 1)                     
    y_values[0] = 1 # y(0) = 1

    # Implement Euler's method
    for i in range(num_steps):
                       
        y_values[i + 1] = y_values[i] + h *f(x_values[i], y_values[i])
        current_exact = np.exp(-2 * x_values[i + 1])
        current_error = abs(current_exact - y_values[i + 1])
        accumulated_error += current_error 
        running_error[i + 1] = accumulated_error
    print(f"Euler Approximation when h = {h}","------>", y_values[-1])
    print("The current error is:","------>", running_error[-1] )
    print(f"The Accumulated error is: {accumulated_error}", '\n')
    plt.plot(x_values, y_values)

# Plot the results
plt.xlabel('x')
plt.ylabel('y')
plt.title("Approximation of dy/dx = -2y using Euler's Method")
plt.show()
# Out:
# Euler Approximation when h = 0.1 ------> 0.01152921504606847
# The current error is: ------> 0.4800469939772947
# The Accumulated error is: 0.4800469939772947
#
# Euler Approximation when h = 0.15000000000000002 ------> 0.009688901040699993
# The current error is: ------> 0.4140378605027559
# The Accumulated error is: 0.4140378605027559
#
# Euler Approximation when h = 0.20000000000000004 ------> 0.010077695999999988
# The current error is: ------> 0.2693037168214072
# The Accumulated error is: 0.2693037168214072
#
# Euler Approximation when h = 0.25000000000000006 ------> 0.007812499999999988
# The current error is: ------> 0.28141238283505643
# The Accumulated error is: 0.28141238283505643
#
# Euler Approximation when h = 0.30000000000000004 ------> 0.004095999999999995
# The current error is: ------> 0.3718866238437199
# The Accumulated error is: 0.3718866238437199
#
# Euler Approximation when h = 0.3500000000000001 ------> 0.002429999999999993
# The current error is: ------> 0.3734912782683902
# The Accumulated error is: 0.3734912782683902
#
# Euler Approximation when h = 0.40000000000000013 ------> 0.0015999999999999912
# The current error is: ------> 0.32171743166465355
# The Accumulated error is: 0.32171743166465355
#
# Euler Approximation when h = 0.45000000000000007 ------> 9.99999999999994e-05
# The current error is: ------> 0.46021743166465334
# The Accumulated error is: 0.46021743166465334
#
# Euler Approximation when h = 0.5000000000000001 ------> -1.0947644252537633e-47
# The current error is: ------> 0.3513962282272627
# The Accumulated error is: 0.3513962282272627
#
# Euler Approximation when h = 0.5500000000000002 ------> -0.0010000000000000096
# The current error is: ------> 0.4423962282272627
# The Accumulated error is: 0.4423962282272627
#
# Euler Approximation when h = 0.6000000000000002 ------> -0.008000000000000049
# The current error is: ------> 0.5193962282272628
# The Accumulated error is: 0.5193962282272628
#
# Euler Approximation when h = 0.6500000000000001 ------> -0.027000000000000066
# The current error is: ------> 0.6294293257816598
# The Accumulated error is: 0.6294293257816598
#
# Euler Approximation when h = 0.7000000000000002 ------> 0.16000000000000025
# The current error is: ------> 0.6770196443478791
# The Accumulated error is: 0.6770196443478791
#
# Euler Approximation when h = 0.7500000000000002 ------> 0.25000000000000044
# The current error is: ------> 0.8670196443478795
# The Accumulated error is: 0.8670196443478795
#
# Euler Approximation when h = 0.8000000000000002 ------> 0.3600000000000003
# The current error is: ------> 1.0770196443478792
# The Accumulated error is: 1.0770196443478792
#
# Euler Approximation when h = 0.8500000000000002 ------> 0.49000000000000066
# The current error is: ------> 1.3070196443478796
# The Accumulated error is: 1.3070196443478796
#
# Euler Approximation when h = 0.9000000000000002 ------> 0.6400000000000008
# The current error is: ------> 1.5570196443478799
# The Accumulated error is: 1.5570196443478799
#
# Euler Approximation when h = 0.9500000000000003 ------> 0.8100000000000009
# The current error is: ------> 1.82701964434788
# The Accumulated error is: 1.82701964434788
