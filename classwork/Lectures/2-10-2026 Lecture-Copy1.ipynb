# %%
for i in range(0,55): #Machine Epsilon 
    print(i, 1+2**(-i))
# Out:
# 0 2
# 1 1.5
# 2 1.25
# 3 1.125
# 4 1.0625
# 5 1.03125
# 6 1.015625
# 7 1.0078125
# 8 1.00390625
# 9 1.001953125
# 10 1.0009765625
# 11 1.00048828125
# 12 1.000244140625
# 13 1.0001220703125
# 14 1.00006103515625
# 15 1.000030517578125
# 16 1.0000152587890625
# 17 1.0000076293945312
# 18 1.0000038146972656
# 19 1.0000019073486328
# 20 1.0000009536743164
# 21 1.0000004768371582
# 22 1.000000238418579
# 23 1.0000001192092896
# 24 1.0000000596046448
# 25 1.0000000298023224
# 26 1.0000000149011612
# 27 1.0000000074505806
# 28 1.0000000037252903
# 29 1.0000000018626451
# 30 1.0000000009313226
# 31 1.0000000004656613
# 32 1.0000000002328306
# 33 1.0000000001164153
# 34 1.0000000000582077
# 35 1.0000000000291038
# 36 1.000000000014552
# 37 1.000000000007276
# 38 1.000000000003638
# 39 1.000000000001819
# 40 1.0000000000009095
# 41 1.0000000000004547
# 42 1.0000000000002274
# 43 1.0000000000001137
# 44 1.0000000000000568
# 45 1.0000000000000284
# 46 1.0000000000000142
# 47 1.000000000000007
# ...

# %%
import numpy as np #Challenge 4
Sum= 0
List = []
for i in range(0, 5000):
    function = 4*(((-1)**i)/(2*i+1))
    Sum += function
    if(i % 100 == 0):
        relative_error= abs((Sum-np.pi)/np.pi)   
        print(relative_error)
# Out:
# 0.2732395447351627
# 0.00315150580387468
# 0.0015836214753932633
# 0.001057505009525431
# 0.000793789005751022
# 0.0006353484414075896
# 0.0005296333874729713
# 0.00045407949250305123
# 0.0003973904646130839
# 0.00035328500350548475
# 0.0003179918149508013
# 0.00028910973709111743
# 0.0002650373280719025
# 0.00024466551819292626
# 0.0002272018883944259
# 0.00021206519044809295
# 0.00019881939733771412
# 0.00018713101627287207
# 0.000176740622792398
# 0.0001674433793591898
# 0.00015907539545632673
# 0.00015150398293974264
# 0.00014462056781363417
# 0.00013833545030563822
# 0.0001325738743772192
# 0.00012727304016872125
# 0.00012237980562142684
# 0.00011784889865893333
# 0.00011364151233219226
# 0.00010972419053097714
# 0.00010606793647030701
# 0.00010264749368209822
# 9.944076176776648e-05
# 9.642831835280076e-05
# 9.359302537720791e-05
# 9.091970285513445e-05
# 8.839485699879063e-05
# 8.600645241284703e-05
# 8.374372025298852e-05
# 8.159699588842421e-05
# 7.955758090949406e-05
# ...
