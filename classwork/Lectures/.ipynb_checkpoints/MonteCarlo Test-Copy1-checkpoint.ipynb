# %%
def PrimeorEven(number)
t= input("Please choose a number between 3 and 1000")

if(number == 0 or 2):
        print("It is an odd number!")
    else:
            print("It is prime!")
return(number)
        
PrimeorEven(4)

# %%
choice = input("Please choose a number between 3 and 1000")

# %%
4+5

# %%
4+5
